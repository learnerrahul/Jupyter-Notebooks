# %% [markdown]
# # Data Presentation and EDA - Movies Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.options.display.max_columns = 30
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# ## Importing the data

# %%
movies=pd.read_csv('movies_complete.csv',parse_dates=['release_date'])

# %%
movies.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %% [markdown]
# ## EDA Analysis - Preliminary Information of the data

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %%
movies.describe()
# Out:
#              id  budget_musd  revenue_musd  vote_count  vote_average  \
# count  44691.00      8854.00       7385.00    44691.00      42077.00
# mean  107186.24        21.67         68.97      111.65          6.00
# std   111806.36        34.36        146.61      495.32          1.28
# min        2.00         0.00          0.00        0.00          0.00
# 25%    26033.50         2.00          2.41        3.00          5.30
# 50%    59110.00         8.20         16.87       10.00          6.10
# 75%   154251.00        25.00         67.64       35.00          6.80
# max   469172.00       380.00       2787.97    14075.00         10.00
#
#        popularity  runtime  cast_size  crew_size
# count    44691.00 43179.00   44691.00   44691.00
# mean         2.96    97.57      12.48      10.31
# std          6.04    34.65      12.12      15.89
# min          0.00     1.00       0.00       0.00
# 25%          0.40    86.00       6.00       2.00
# ...

# %%
movies.genres
# Out:
# 0         Animation|Comedy|Family
# 1        Adventure|Fantasy|Family
# 2                  Romance|Comedy
# 3            Comedy|Drama|Romance
# 4                          Comedy
#                    ...
# 44686                Drama|Family
# 44687                       Drama
# 44688       Action|Drama|Thriller
# 44689                         NaN
# 44690                         NaN
# Name: genres, Length: 44691, dtype: object

# %%
movies.cast
# Out:
# 0        Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 1        Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 2        Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...
# 3        Whitney Houston|Angela Bassett|Loretta Devine|...
# 4        Steve Martin|Diane Keaton|Martin Short|Kimberl...
#                                ...
# 44686              Leila Hatami|Kourosh Tahami|Elham Korda
# 44687    Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...
# 44688    Erika Eleniak|Adam Baldwin|Julie du Page|James...
# 44689    Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...
# 44690                                                  NaN
# Name: cast, Length: 44691, dtype: object

# %%
movies.hist(figsize = (15, 12), bins = 100)
plt.show()

# %%
movies.revenue_musd.value_counts(dropna= False).head(25)
# Out:
# NaN      37306
# 12.00       20
# 10.00       19
# 11.00       19
# 2.00        18
# 6.00        17
# 5.00        14
# 0.50        13
# 8.00        13
# 0.00        12
# 14.00       12
# 7.00        11
# 3.00        10
# 1.00        10
# 20.00       10
# 0.00         9
# 1.50         9
# 4.00         9
# 30.00        8
# 4.10         8
# 15.00        8
# 16.00        8
# 25.00        8
# 2.50         8
# 4.30         7
# Name: revenue_musd, dtype: int64

# %%
movies.budget_musd.value_counts(dropna = False).head(25)
# Out:
# NaN      35837
# 5.00       286
# 10.00      258
# 20.00      243
# 2.00       241
# 15.00      226
# 3.00       220
# 25.00      206
# 1.00       195
# 30.00      189
# 4.00       180
# 6.00       173
# 12.00      171
# 40.00      166
# 8.00       155
# 35.00      141
# 0.50       141
# 7.00       137
# 50.00      124
# 1.50       119
# 60.00      110
# 18.00      104
# 3.50       103
# 2.50        98
# 13.00       89
# Name: budget_musd, dtype: int64

# %%
movies.vote_average.value_counts(dropna = False)
# Out:
# NaN     2614
# 6.00    2421
# 5.00    1969
# 7.00    1859
# 6.50    1705
#         ...
# 9.40       3
# 9.60       1
# 9.80       1
# 0.70       1
# 1.10       1
# Name: vote_average, Length: 93, dtype: int64

# %%
movies.vote_count.value_counts(dropna = False)
# Out:
# 1.00       3186
# 2.00       3056
# 3.00       2729
# 0.00       2614
# 4.00       2442
#            ...
# 2755.00       1
# 1187.00       1
# 4200.00       1
# 3322.00       1
# 2712.00       1
# Name: vote_count, Length: 1820, dtype: int64

# %%
movies.describe(include = "object")
# Out:
#              title                 tagline genres belongs_to_collection  \
# count        44691                   20284  42586                  4463
# unique       41605                   20171   4044                  1691
# top     Cinderella  Based on a true story.  Drama       The Bowery Boys
# freq            11                       7   4935                    29
#
#        original_language       production_companies      production_countries  \
# count              44681                      33356                     38835
# unique                89                      22537                      2377
# top                   en  Metro-Goldwyn-Mayer (MGM)  United States of America
# freq               31755                        741                     17723
#
#                                     overview spoken_languages  \
# count                                  43740            41094
# unique                                 43715             1828
# ...

# %%
movies[movies.title == "Cinderella"]
# Out:
#            id       title                             tagline release_date  \
# 984     11224  Cinderella  The greatest love story ever told.   1950-03-04
# 12988   42884  Cinderella                                 NaN   1997-11-02
# 23254   92349  Cinderella                                 NaN   1914-12-28
# 23265  105875  Cinderella          The version children love!   2002-08-06
# 28073  261985  Cinderella                                 NaN   2011-10-30
# 28340  150689  Cinderella     Midnight is just the beginning.   2015-03-12
# 33805   42651  Cinderella                                 NaN   1947-11-28
# 35114   44459  Cinderella                                 NaN   1957-03-31
# 35116  289673  Cinderella                                 NaN   2000-01-01
# 40439  114108  Cinderella                                 NaN   1899-10-01
# 44633   98604  Cinderella                                 NaN   2012-02-14
#
# ...

# %% [markdown]
# ## Filtering out Best and Worst movies - profit/revenue/ROI

# %% [markdown]
# ### Integrating HTML for better viewing experience

# %%
from IPython.display import HTML
pd.options.display.max_colwidth = 200

# %% [markdown]
# ### Best Movies

# %%
movies_best = movies[["poster_path", "title", "budget_musd", "revenue_musd",
              "vote_count", "vote_average", "popularity"]].copy()
movies_best
# Out:
#                                                                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
# ...                                                                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8gZ1BQANxxdadIMpdywbPG9X.jpg' style='height:100px;'>
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg' style='height:100px;'>
# ...

# %%
movies_best["profit_musd"] = movies.revenue_musd.sub(movies.budget_musd)
movies_best["return"] = movies.revenue_musd.div(movies.budget_musd)
movies_best
# Out:
#                                                                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
# ...                                                                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8gZ1BQANxxdadIMpdywbPG9X.jpg' style='height:100px;'>
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg' style='height:100px;'>
# ...

# %%
movies_best.columns = ["", "Title", "Budget", "Revenue", "Votes", 
                   "Average Rating", "Popularity", "Profit", "ROI"]

# %%
movies_best.set_index("Title", inplace = True)
movies_best
# Out:
#                                                                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
# ...                                                                                                                        ...
# ...

# %%
movies_best.iloc[1,0]
# Out:
# "<img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>"

# %% [markdown]
# ### Improving Asthetics of the data by experimenting on a subset

# %%
subset = movies_best.iloc[:10, :2]
subset
# Out:
#                                                                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
# Heat                         <img src='http://image.tmdb.org/t/p/w185//lbf2ueoiEfKIJr2qlT01zIEckbC.jpg' style='height:100px;'>
# ...

# %%
HTML(subset.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'></td>
#       <td>30.00</td>
#     </tr>
#     <tr>
#       <th>Jumanji</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'></td>
#       <td>65.00</td>
#     </tr>
#     <tr>
#       <th>Grumpier Old Men</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Waiting to Exhale</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'></td>
# ...

# %% [markdown]
# # Evauluating performances- Best Movies

# %%
movies_best.Budget.fillna(0, inplace = True)
movies_best.Votes.fillna(0, inplace = True)
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %%
movies_best.loc[movies_best.Budget >= 5].sort_values(by = "ROI", ascending = False)
# Out:
#                                                                                                                                                    \
# Title
# E.T. the Extra-Terrestrial                      <img src='http://image.tmdb.org/t/p/w185//cBfkE3HSH1NOyy1ftxlPw2l3ukb.jpg' style='height:100px;'>
# My Big Fat Greek Wedding                        <img src='http://image.tmdb.org/t/p/w185//3TB2GJqWS9Ro4JdfV6FP87v3etE.jpg' style='height:100px;'>
# Star Wars                                       <img src='http://image.tmdb.org/t/p/w185//6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg' style='height:100px;'>
# Jaws                                            <img src='http://image.tmdb.org/t/p/w185//s2xcqSFfT6F7ZXHxowjxfG0yisT.jpg' style='height:100px;'>
# Crocodile Dundee                                <img src='http://image.tmdb.org/t/p/w185//kiwOZXU7ddSrWE3ryOQM8sIg1sZ.jpg' style='height:100px;'>
# ...

# %%
#Creating fuction  best_worst for ease of excecution with changeable parameters

def best_worst(n, by, ascending = False, min_bud = 0, min_votes = 0):
    
    
    movies2 = movies_best.loc[(movies_best.Budget >= min_bud) & (movies_best.Votes >= min_votes), 
                      ["", by]].sort_values(by = by, ascending = ascending).head(n).copy()
    
    return HTML(movies2.to_html(escape=False))

# %% [markdown]
# ## Performance Analysis - Best and Worst

# %% [markdown]
# ### Top 10 movies - Highest Budget

# %%
best_worst(10, "Budget")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.00</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.00</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.00</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
# ...

# %% [markdown]
# ### Top 10 movies - Highest Renue

# %%
best_worst(10,"Revenue")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2787.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>2068.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1845.03</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
# ...

# %% [markdown]
# ### Top 10 movies - Most Profitable

# %%
best_worst(10,'Profit')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2550.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>1823.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1645.03</td>
#     </tr>
#     <tr>
#       <th>Jurassic World</th>
# ...

# %% [markdown]
# ### Top 10 movies -  Least Profitable

# %%
best_worst(10,'Profit', ascending= True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Lone Ranger</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//b2je2ZybNIzAOL1K1WPbbT6zt2M.jpg' style='height:100px;'></td>
#       <td>-165.71</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>-119.18</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lOKqLd0ud1wdwaPK5h6bGNZIVLT.jpg' style='height:100px;'></td>
#       <td>-111.01</td>
#     </tr>
#     <tr>
#       <th>Valerian and the City of a Thousand Planets</th>
# ...

# %% [markdown]
# ### Top 10 movies -  Highest ROI

# %%
best_worst(10,'ROI',min_bud=20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Ghost</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//w9RaPHov8oM5cnzeE27isnFMsvS.jpg' style='height:100px;'></td>
#       <td>22.95</td>
#     </tr>
#     <tr>
#       <th>The Passion of the Christ</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4l9LCSOfEJ0vSY9D6kpH2OVfk0j.jpg' style='height:100px;'></td>
#       <td>20.40</td>
#     </tr>
#     <tr>
#       <th>Dances with Wolves</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//cvaBVpS0GzKqBd63pFT8f1E8OKv.jpg' style='height:100px;'></td>
#       <td>19.28</td>
#     </tr>
#     <tr>
#       <th>Aladdin</th>
# ...

# %% [markdown]
# ### Top 10 movies -  Lowest ROI

# %%
best_worst(10,'ROI',min_bud=20,ascending = True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Chasing Liberty</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7qzvS9QKkiDcz1K8EY9Y6ZXkUeD.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>The Adventurer: The Curse of the Midas Box</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//31ykUoOS2RNdARk3B8z3y25gD8b.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Chaos</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//wSZYVssIv4kjRJuyimzc1gBJC2e.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>5 Days of War</th>
# ...

# %% [markdown]
# ### Top 10 movies -  Movies with most number of votes

# %%
best_worst(10, 'Votes',min_votes=100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Votes</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Inception</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg' style='height:100px;'></td>
#       <td>14075.00</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>12269.00</td>
#     </tr>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>12114.00</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
# ...

# %% [markdown]
# ### Top 10 movies -  Highest Rated Movies

# %%
best_worst(10,'Average Rating',min_votes=100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Dilwale Dulhania Le Jayenge</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2CAL2433ZeIihfX1Hb2139CX0pW.jpg' style='height:100px;'></td>
#       <td>9.10</td>
#     </tr>
#     <tr>
#       <th>Planet Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//koVzjt54bJEVuKTmGC4cExcbE2w.jpg' style='height:100px;'></td>
#       <td>8.80</td>
#     </tr>
#     <tr>
#       <th>Your Name.</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//iaiy3tg9QVkDpObm1IGqmbC9A5C.jpg' style='height:100px;'></td>
#       <td>8.50</td>
#     </tr>
#     <tr>
#       <th>The Shawshank Redemption</th>
# ...

# %% [markdown]
# ### Top 10 movies -  Highest Rated Movies - Most Popular movies

# %%
best_worst(10,'Popularity',min_votes=100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Popularity</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>547.49</td>
#     </tr>
#     <tr>
#       <th>Wonder Woman</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gfJGlDaHuWimErCr5Ql0I8x9QSy.jpg' style='height:100px;'></td>
#       <td>294.34</td>
#     </tr>
#     <tr>
#       <th>Beauty and the Beast</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tWqifoYuwLETmmasnGHO7xBjEtt.jpg' style='height:100px;'></td>
#       <td>287.25</td>
#     </tr>
#     <tr>
#       <th>Baby Driver</th>
# ...

# %% [markdown]
# ## Find the next movie to watch based on user preferences

# %% [markdown]
# ### Science fiction / Action movies with Tom Cruise

# %%
movies.genres
# Out:
# 0         Animation|Comedy|Family
# 1        Adventure|Fantasy|Family
# 2                  Romance|Comedy
# 3            Comedy|Drama|Romance
# 4                          Comedy
#                    ...
# 44686                Drama|Family
# 44687                       Drama
# 44688       Action|Drama|Thriller
# 44689                         NaN
# 44690                         NaN
# Name: genres, Length: 44691, dtype: object

# %%
mask_genres = movies.genres.str.contains("Action") & movies.genres.str.contains("Science Fiction")
mask_genres
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: genres, Length: 44691, dtype: bool

# %%
mask_actor = movies.cast.str.contains("Tom Cruise")
mask_actor
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690      NaN
# Name: cast, Length: 44691, dtype: object

# %%
tom = movies.loc[mask_actor & mask_genres, ["title", "poster_path", "vote_average"]].sort_values(by = "vote_average", ascending = False).set_index("title")

# %%
HTML(tom.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Edge of Tomorrow</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uUHvlkLavotfGsNtosDy8ShsIYF.jpg' style='height:100px;'></td>
#       <td>7.60</td>
#     </tr>
#     <tr>
#       <th>Minority Report</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//q8dbg0WhfbCJDCrfXWTOzJoVDnV.jpg' style='height:100px;'></td>
#       <td>7.10</td>
#     </tr>
#     <tr>
#       <th>Oblivion</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2ncs7hqBsEjFMqt6Y7ShBCO9tWs.jpg' style='height:100px;'></td>
#       <td>6.40</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Movies with Martin Scorses (Director) and Leonardo DiCaprio

# %%
movies.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 44686    Hamid Nematollah
# 44687            Lav Diaz
# 44688      Mark L. Lester
# 44689    Yakov Protazanov
# 44690       Daisy Asquith
# Name: director, Length: 44691, dtype: object

# %%
mask_director = movies.director == "Martin Scorsese"

# %%
mask_actor = movies.cast.str.contains("Leonardo DiCaprio")

# %%
martin_leo = movies.loc[mask_director & mask_actor, 
               ["title", "poster_path", "runtime"]].sort_values(by = "runtime").set_index("title")

# %%
HTML(martin_leo.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>runtime</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Shutter Island</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//kve20tXwUZpu4GUX8l6X7Z4jmL6.jpg' style='height:100px;'></td>
#       <td>138.00</td>
#     </tr>
#     <tr>
#       <th>The Departed</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//p3tmqqwFPHFdu1oVpcgKGfcPCMZ.jpg' style='height:100px;'></td>
#       <td>151.00</td>
#     </tr>
#     <tr>
#       <th>Gangs of New York</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lemqKtcCuAano5aqrzxYiKC8kkn.jpg' style='height:100px;'></td>
#       <td>167.00</td>
#     </tr>
#     <tr>
#       <th>The Aviator</th>
# ...

# %% [markdown]
# ## Most Successful movies (by profit) of Warner Bros. [1990-2020]

# %%
movies.production_companies[10]
# Out:
# 'Columbia Pictures|Castle Rock Entertainment'

# %%
mask_studio = movies.production_companies.str.contains("Warner").fillna(False)

# %%
mask_time = movies.release_date.between("1990-01-01", "2020-12-31")

# %%
warner = movies.loc[mask_studio & mask_time, 
               ["title", "poster_path", "revenue_musd", "release_date"]].sort_values(by = "revenue_musd", ascending = False).set_index("title")

# %%
HTML(warner.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>revenue_musd</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Harry Potter and the Deathly Hallows: Part 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//c54HpQmuwXjHq2C9wmoACjxoom3.jpg' style='height:100px;'></td>
#       <td>1342.00</td>
#       <td>2011-07-07</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight Rises</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vzvKcPQ4o7TjWeGIn0aGC9FeVNu.jpg' style='height:100px;'></td>
#       <td>1084.94</td>
#       <td>2012-07-16</td>
#     </tr>
#     <tr>
#       <th>The Hobbit: An Unexpected Journey</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qQeVJAvx6YCRGqaaZZpPm1WxMv6.jpg' style='height:100px;'></td>
# ...

# %% [markdown]
# ### Highly Rated Romance Comedy Movies (English)

# %%
mask_genre = movies.genres.str.contains("Romance") | movies.genres.str.contains("Comedy")

# %%
mask_lan = movies.original_language == "en"

# %%
mask_vote_av = movies.vote_average >= 7 
mask_vote_co = movies.vote_count >= 150

# %%
rom_com = movies.loc[mask_genre & mask_lan & mask_vote_av & mask_vote_co, 
               ["title", "poster_path", "genres", "vote_average", "vote_count", "release_date"]].sort_values(by = "release_date", ascending = False).set_index("title").head(20)

# %%
HTML(rom_com.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>genres</th>
#       <th>vote_average</th>
#       <th>vote_count</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Descendants 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8BNyZlBk4Hs92z6UrvFDjvx3yMb.jpg' style='height:100px;'></td>
#       <td>TV Movie|Family|Action|Comedy|Music|Adventure</td>
#       <td>7.50</td>
#       <td>171.00</td>
#       <td>2017-07-21</td>
#     </tr>
#     <tr>
#       <th>Girls Trip</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//mdsHCFt2PeZacEr38y2p5RRf6Hl.jpg' style='height:100px;'></td>
#       <td>Comedy</td>
#       <td>7.10</td>
#       <td>393.00</td>
#       <td>2017-07-21</td>
#     </tr>
# ...

# %% [markdown]
# ## Franchises Vs Stand-Alone Movies - Which one More Successful?

# %%
movies.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 44686                               NaN
# 44687                               NaN
# 44688                               NaN
# 44689                               NaN
# 44690                               NaN
# Name: belongs_to_collection, Length: 44691, dtype: object

# %%
movies["Franchise"] = movies.belongs_to_collection.notna()

# %%
movies.Franchise
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: Franchise, Length: 44691, dtype: bool

# %%
movies.Franchise.value_counts()
# Out:
# False    40228
# True      4463
# Name: Franchise, dtype: int64

# %% [markdown]
# ###  Franchise Vs Stand-alone: Average Revenue

# %%
movies.groupby("Franchise").revenue_musd.mean()
# Out:
# Franchise
# False    44.74
# True    165.71
# Name: revenue_musd, dtype: float64

# %% [markdown]
# ###  Franchise Vs Stand-alone : Budget

# %%
movies.groupby("Franchise").budget_musd.mean()
# Out:
# Franchise
# False   18.05
# True    38.32
# Name: budget_musd, dtype: float64

# %% [markdown]
# ###  Franchise Vs Stand-alone :ROI and Profitability

# %%
movies["ROI"] = movies.revenue_musd.div(movies.budget_musd)

# %%
movies.groupby("Franchise").ROI.median()
# Out:
# Franchise
# False   1.62
# True    3.71
# Name: ROI, dtype: float64

# %% [markdown]
# ###  Franchise Vs Stand-alone : Popularity

# %%
movies.groupby("Franchise").popularity.mean()
# Out:
# Franchise
# False   2.59
# True    6.25
# Name: popularity, dtype: float64

# %% [markdown]
# ###  Franchise Vs Stand-alone : Average Rating

# %%
movies.groupby("Franchise").vote_average.mean()
# Out:
# Franchise
# False   6.01
# True    5.96
# Name: vote_average, dtype: float64

# %%
movies.groupby("Franchise").agg({"budget_musd": "mean", "revenue_musd": "mean", "vote_average": "mean",
                            "popularity": "mean", "ROI":"median", "vote_count":"mean"})
# Out:
#            budget_musd  revenue_musd  vote_average  popularity  ROI  \
# Franchise
# False            18.05         44.74          6.01        2.59 1.62
# True             38.32        165.71          5.96        6.25 3.71
#
#            vote_count
# Franchise
# False           78.29
# True           412.39

# %% [markdown]
# ### Conclusion - Franchises tend to be more profitable than Stand-alone projects

# %% [markdown]
# ## Analysis of most Successful Franchises

# %%
movies.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 44686                               NaN
# 44687                               NaN
# 44688                               NaN
# 44689                               NaN
# 44690                               NaN
# Name: belongs_to_collection, Length: 44691, dtype: object

# %%
movies.belongs_to_collection.value_counts()
# Out:
# The Bowery Boys                  29
# Totò Collection                  27
# Zatôichi: The Blind Swordsman    26
# James Bond Collection            26
# The Carry On Collection          25
#                                  ..
# Salt and Pepper Collection        1
# Deadpool Collection               1
# Ant-Man Collection                1
# Elvira Collection                 1
# Red Lotus Collection              1
# Name: belongs_to_collection, Length: 1691, dtype: int64

# %%
franchises = movies.groupby("belongs_to_collection").agg({"title":"count", "budget_musd": ["sum", "mean"], 
                                                      "revenue_musd": ["sum", "mean"],
                                                      "vote_average": "mean", "popularity": "mean",
                                                      "ROI":"median", 
                                                      "vote_count":"mean"})
franchises
# Out:
#                                      title budget_musd       revenue_musd  \
#                                      count         sum  mean          sum
# belongs_to_collection
# ... Has Fallen Collection                2      130.00 65.00       366.78
# 00 Schneider Filmreihe                   1        0.00   NaN         0.00
# 08/15 Collection                         1        0.00   NaN         0.00
# 100 Girls Collection                     2        0.00   NaN         0.00
# 101 Dalmatians (Animated) Collection     2        4.00  4.00       215.88
# ...                                    ...         ...   ...          ...
# Сказки Чуковского                        1        0.00   NaN         0.00
# Чебурашка и крокодил Гена                1        0.00   NaN         0.00
# Что Творят мужчины! (Коллекция)          2        2.00  2.00         0.00
# 男はつらいよ シリーズ                              3        0.00   NaN         0.00
# ...

# %%
franchises.nlargest(20, ("revenue_musd", "mean"))
# Out:
#                                     title budget_musd        revenue_musd  \
#                                     count         sum   mean          sum
# belongs_to_collection
# Avatar Collection                       1      237.00 237.00      2787.97
# The Avengers Collection                 2      500.00 250.00      2924.96
# Frozen Collection                       2      150.00 150.00      1274.22
# Finding Nemo Collection                 2      294.00 147.00      1968.91
# The Hobbit Collection                   3      750.00 250.00      2935.52
# The Lord of the Rings Collection        3      266.00  88.67      2916.54
# Harry Potter Collection                 8     1280.00 160.00      7707.37
# Star Wars Collection                    8      854.35 106.79      7434.49
# Despicable Me Collection                6      299.00  74.75      3691.07
# Pirates of the Caribbean Collection     5     1250.00 250.00      4521.58
# ...

# %%
franchises.nlargest(20, ("title", "count"))
# Out:
#                                        title budget_musd       revenue_musd  \
#                                        count         sum  mean          sum
# belongs_to_collection
# The Bowery Boys                           29        0.00   NaN         0.00
# Totò Collection                           27        0.00   NaN         0.00
# James Bond Collection                     26     1539.65 59.22      7106.97
# Zatôichi: The Blind Swordsman             26        0.00   NaN         0.00
# The Carry On Collection                   25        0.00   NaN         0.00
# Charlie Chan (Sidney Toler) Collection    21        0.00   NaN         0.00
# Pokémon Collection                        20      250.72 50.14       601.87
# Godzilla (Showa) Collection               16        2.81  0.56         0.00
# Charlie Chan (Warner Oland) Collection    15        0.00   NaN         0.00
# Dragon Ball Z (Movie) Collection          15        5.00  5.00       112.12
# ...

# %%
franchises.nlargest(20, ("budget_musd", "mean"))
# Out:
#                                         title budget_musd        revenue_musd  \
#                                         count         sum   mean          sum
# belongs_to_collection
# Tangled Collection                          2      260.00 260.00       591.79
# Pirates of the Caribbean Collection         5     1250.00 250.00      4521.58
# The Avengers Collection                     2      500.00 250.00      2924.96
# The Hobbit Collection                       3      750.00 250.00      2935.52
# Man of Steel Collection                     2      475.00 237.50      1536.11
# Avatar Collection                           1      237.00 237.00      2787.97
# The Amazing Spider-Man Collection           2      415.00 207.50      1457.93
# World War Z Collection                      1      200.00 200.00       531.87
# Spider-Man Collection                       3      597.00 199.00      2496.35
# The Dark Knight Collection                  3      585.00 195.00      2463.72
# ...

# %%
franchises[franchises[("vote_count", "mean")] >=1000].nlargest(20, ("vote_average", "mean"))
# Out:
#                                     title budget_musd        revenue_musd  \
#                                     count         sum   mean          sum
# belongs_to_collection
# The Lord of the Rings Collection        3      266.00  88.67      2916.54
# The Godfather Collection                3       73.00  24.33       429.38
# Blade Runner Collection                 1       28.00  28.00        33.14
# The Man With No Name Collection         3        2.00   0.67        35.50
# The Dark Knight Collection              3      585.00 195.00      2463.72
# Guardians of the Galaxy Collection      2      370.00 185.00      1636.74
# Kill Bill Collection                    2       60.00  30.00       333.11
# Kingsman Collection                     1       81.00  81.00       414.35
# How to Train Your Dragon Collection     2      310.00 155.00      1104.00
# Harry Potter Collection                 8     1280.00 160.00      7707.37
# ...
